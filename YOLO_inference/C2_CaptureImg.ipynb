# %% [markdown]
# Configure home directory and YOLO install

# %%
import os
HOME = os.getcwd()
print(HOME)

# Import YOLO
# from IPython import display
# display.clear_output()
# !yolo checks
from ultralytics import YOLO
from IPython.display import display, Image

# Import CV2
import cv2
import time
# Out:
# /home/alex/ForeHelm/YOLO_example

# %% [markdown]
# Minimum code for capturing an img

# %%
img_path = "img/captured_image.jpg"
if os.path.exists(img_path):
    os.remove(img_path)
    print(f"Previous img '{img_path}' has been removed.")

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
cap.set(cv2.CAP_PROP_FPS, 30)

status, photo = cap.read()
cv2.imwrite(img_path, photo)
cap.release()

print(f"Time taken to capture and save the image: {elapsed_time:.4f} seconds")
Image(filename=img_path, height=640)
# Out:
# Previous img 'img/captured_image.jpg' has been removed.
# Time taken to capture and save the image: 0.5649 seconds

# %% [markdown]
# Capture an image and measure the time it takes for it
# - Remove image if there is a previous one.
# - Capture a new image and store it in img/captured_image.jpg

# %%
img_path = "img/captured_image.jpg"
if os.path.exists(img_path):
    os.remove(img_path)
    print(f"Previous img '{img_path}' has been removed.")

cap = cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
cap.set(cv2.CAP_PROP_FPS, 30)

start_time = time.time()
status, photo = cap.read()
end_time = time.time()
cv2.imwrite(img_path, photo)
cap.release()


elapsed_time = end_time - start_time
print(f"Time taken to capture and save the image: {elapsed_time:.4f} seconds")
Image(filename=img_path, height=640)
# Out:
# Previous img 'img/captured_image.jpg' has been removed.
# Time taken to capture and save the image: 0.5602 seconds

# %% [markdown]
# Capture img with brightness adjust

# %%
img_path = "img/captured_image_bright.jpg"
if os.path.exists(img_path):
    os.remove(img_path)
    print(f"Previous img '{img_path}' has been removed.")

cap = cv2.VideoCapture(0)
status, photo = cap.read()

# Adjust brightness
brightness_value = 40  # Increase this value for more brightness
bright_photo = cv2.convertScaleAbs(photo, alpha=1, beta=brightness_value)

# Save the brightened image
cv2.imwrite(img_path, bright_photo)

# Release the camera
cap.release()

Image(filename=img_path, height=640)
# Out:
# Previous img 'img/captured_image_bright.jpg' has been removed.

# %%
# import cv2
# cap = cv2.VideoCapture(0)
# while True:
#    status, photo = cap.read()
#    cv2.imshow("Streaming Video", photo)
#    if cv2.waitKey(10) == 13:
#       break
# cv2.destroyAllWindows()
